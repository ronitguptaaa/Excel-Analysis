# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/ronitguptaaa/Documents/Excel Analysis/OrderSales/1-Learn-Data.csv')
display(df)
# Out:
#       Employee ID  Last Name First Name  Customer ID  Order ID  Quantity  \
# 0               1    Davolio      Nancy            1         1         1
# 1               3  Leverling      Janet           41      1002         3
# 2               3  Leverling      Janet           41      1002         3
# 3               4    Peacock   Margaret           77      1003         3
# 4               4    Peacock   Margaret           77      1003         3
# ...           ...        ...        ...          ...       ...       ...
# 3679            7       King     Robert          266      3189         2
# 3680            7       King     Robert          267      3190         1
# 3681            9  Dodsworth       Anne          268      3191         3
# 3682            1    Davolio      Nancy          269      3192         2
# 3683            1    Davolio      Nancy          270      3193         2
#
#       Price (SRP)  Product ID                   Product Name  Order Date  \
# ...
